# %% [markdown]
# # Domain-Calibrated Quad-Channel Hybrid
# This notebook represents Phase 4 of the architecture. It implements a two-ranker system (structural and spectral) while actively filtering out noisy priors like the ChEBI database to close the domain gap between synthetic training data and the hidden test set.
#
# **Note:** This model is designed to leverage GPU acceleration (FP16 precision) for deeper feature extraction.
